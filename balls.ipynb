# %% [markdown]
# # Imports

# %%
### Uncomment and run once
# %pip install sklearn
# %pip install pandas
# %pip install matplotlib
# %pip install seaborn
# %pip install numpy

# %%
import sklearn
import pandas
import matplotlib
import seaborn
import numpy
